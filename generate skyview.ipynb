# %%
#I want to prepare image data from the kaggle galaxyzoo into 64x64 vector, need the resolution to be high,

# %%
#first, how do I import an image into here as pixel values?

#lets use scipy since I know i have that installed
#http://scipy-lectures.org/advanced/image_processing/

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
galaxyzoo = pd.read_csv("zoo2MainSpecz.csv/zoo2MainSpecz.csv", usecols=[2,3,4,8], nrows=10000)
ID = galaxyzoo["dr7objid"].values
RA = galaxyzoo["ra"].values
DEC = galaxyzoo["dec"].values
Class = galaxyzoo["gz2class"].values

# %%
from astroquery.skyview import SkyView
import astropy.units as u

# %%
for i in range(10000):
    RA[i] = np.round(RA[i],5)
    DEC[i] = np.round(DEC[i],5)

# %%
print(RA[1416],DEC[1416])
# Out:
# 165.04015 45.91702

# %%
#empty_image = np.empty((5,64,64))
#for i in range(5):
#    empty_image[i] = img_list[i][0].data

# %%
#print(np.shape(empty_image))
img = SkyView.get_images(position=((str(RA[1385])+','+str(DEC[1385]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(64,64), radius=200*u.arcsec)
print(img)
print(type(img))
# Out:
# []
# <class 'list'>

# %%
def pre_process_images(RA,DEC,pixel_number = 64,image_number = 2, start=0, radius=200):
    """
    This function will take in an N dimensional RA and DEC array, look up image files from skyquery, place those files in a
    flattened array.
    
    Parameters:
    RA, array, hold right ascensions for object i, N dim
    DEC, array, holds declination for object i, N dim
    pixel_number, int, tells the square pixel size of the skyquery
    image_number, int, tells how many images to pull from our N dim, sets dim of output array
    
    OUTPUT:
    processed_data: array with dimensions: (image_number, pixelnumber*pixelnumber), flattened pixel array
    """
    processed_data = np.empty((image_number-start,pixel_number,pixel_number,5))
    radius = radius*u.arcsec
    for i in range(image_number-start):
        img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=radius)
        #img_green = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSr'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #img_red = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSi'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #print(img)
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/2)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        empty_image = np.empty((pixel_number,pixel_number,5))
        for j in range(5):
            empty_image[:,:,j] = img[j][0].data
        #if i == 0:
        #    print(img[0][0].header)
        #processed_data[i,:,:,:] = empty_image
        save_string = 'array_number_'+str(i+start)
        np.save('C:\\Users\qwsaz\\Research_NCSA\\image_arrays\\{}'.format(save_string), empty_image)
        print(i+start)
    
#should run in 8 hours to go through 10,000 images. 
def pre_process_images(RA,DEC,pixel_number = 64,image_number = 2, start=0, radius=200):
    """
    This function will take in an N dimensional RA and DEC array, look up image files from skyquery, place those files in a
    flattened array.
    
    Parameters:
    RA, array, hold right ascensions for object i, N dim
    DEC, array, holds declination for object i, N dim
    pixel_number, int, tells the square pixel size of the skyquery
    image_number, int, tells how many images to pull from our N dim, sets dim of output array
    
    OUTPUT:
    processed_data: array with dimensions: (image_number, pixelnumber*pixelnumber), flattened pixel array
    """
    processed_data = np.empty((image_number-start,pixel_number,pixel_number,5))
    radius = radius*u.arcsec
    for i in range(image_number-start):
        img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=radius)
        #img_green = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSr'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #img_red = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSi'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #print(img)
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/2)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/4)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/8)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/20)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        empty_image = np.zeros((pixel_number,pixel_number,5))
        if img == []:
            img = np.zeros((64,64,5))
            print('@#$% {} is all zeros'.format(i+start))  
        else:
            for j in range(5):
                empty_image[:,:,j] = img[j][0].data
        #if i == 0:
        #    print(img[0][0].header)
        #processed_data[i,:,:,:] = empty_image
        save_string = 'array_number_'+str(i+start)
        np.save('C:\\Users\qwsaz\\Research_NCSA\\image_arrays\\{}'.format(save_string), empty_image)
        print(i+start)
    
#should run in 8 hours to go through 10,000 images.

# %%
#1292 doesn't exist? we could probably get the same data in a different way, or try again later
#1385 doesn't exist?
#1410 doesn't exist
#1412 wtf
#1416
#1423
#1516 all zeros - 1530
#1686 HTTP error???
#4040
#4459
#4859
#5151
#5344
(processed_data_one) = pre_process_images(RA,DEC,pixel_number = 64,image_number = 10000, start=5345)
# Out:
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218943426491_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218943426491_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218943426491_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218943426491_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218943426491_5.fits [Done]
# 5345
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218988075529_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218988075529_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218988075529_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218988075529_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13218988075529_5.fits [Done]
# 5346
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636751440606_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636751440606_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636751440606_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636751440606_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636751440606_5.fits [Done]
# 5347
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636782310876_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636782310876_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636782310876_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636782310876_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636782310876_5.fits [Done]
# 5348
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219108931364_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219108931364_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219108931364_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219108931364_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219108931364_5.fits [Done]
# 5349
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219146762269_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219146762269_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219146762269_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219146762269_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219146762269_5.fits [Done]
# 5350
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636896699115_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636896699115_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636896699115_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636896699115_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1636896699115_5.fits [Done]
# 5351
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219221462338_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219221462338_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219221462338_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219221462338_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219221462338_5.fits [Done]
# 5352
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219266640514_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219266640514_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219266640514_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219266640514_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219266640514_5.fits [Done]
# 5353
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219298668207_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219298668207_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219298668207_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219298668207_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219298668207_5.fits [Done]
# 5354
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637059878189_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637059878189_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637059878189_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637059878189_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637059878189_5.fits [Done]
# 5355
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219386452791_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219386452791_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219386452791_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219386452791_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219386452791_5.fits [Done]
# 5356
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637150292057_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637150292057_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637150292057_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637150292057_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637150292057_5.fits [Done]
# 5357
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637197911114_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637197911114_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637197911114_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637197911114_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637197911114_5.fits [Done]
# 5358
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219523688497_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219523688497_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219523688497_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219523688497_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219523688497_5.fits [Done]
# 5359
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219558926360_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219558926360_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219558926360_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219558926360_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219558926360_5.fits [Done]
# 5360
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637301347856_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637301347856_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637301347856_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637301347856_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637301347856_5.fits [Done]
# 5361
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219626562706_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219626562706_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219626562706_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219626562706_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13219626562706_5.fits [Done]
# 5362
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637370852478_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637370852478_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637370852478_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637370852478_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1637370852478_5.fits [Done]
# 5363
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13