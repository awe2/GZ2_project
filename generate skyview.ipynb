# %%
#I want to prepare image data from the kaggle galaxyzoo into 64x64 vector, need the resolution to be high,

# %%
#first, how do I import an image into here as pixel values?

#lets use scipy since I know i have that installed
#http://scipy-lectures.org/advanced/image_processing/

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
galaxyzoo = pd.read_csv("zoo2MainSpecz.csv/zoo2MainSpecz.csv", usecols=[2,3,4,8], nrows=10000)
ID = galaxyzoo["dr7objid"].values
RA = galaxyzoo["ra"].values
DEC = galaxyzoo["dec"].values
Class = galaxyzoo["gz2class"].values

# %%
from astroquery.skyview import SkyView
import astropy.units as u

# %%
for i in range(10000):
    RA[i] = np.round(RA[i],5)
    DEC[i] = np.round(DEC[i],5)

# %%
print(RA[1416],DEC[1416])
# Out:
# 165.04015 45.91702

# %%
#empty_image = np.empty((5,64,64))
#for i in range(5):
#    empty_image[i] = img_list[i][0].data

# %%
#print(np.shape(empty_image))
img = SkyView.get_images(position=((str(RA[1385])+','+str(DEC[1385]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(64,64), radius=200*u.arcsec)
print(img)
print(type(img))
# Out:
# []
# <class 'list'>

# %%
def pre_process_images(RA,DEC,pixel_number = 64,image_number = 2, start=0, radius=200):
    """
    This function will take in an N dimensional RA and DEC array, look up image files from skyquery, place those files in a
    flattened array.
    
    Parameters:
    RA, array, hold right ascensions for object i, N dim
    DEC, array, holds declination for object i, N dim
    pixel_number, int, tells the square pixel size of the skyquery
    image_number, int, tells how many images to pull from our N dim, sets dim of output array
    
    OUTPUT:
    processed_data: array with dimensions: (image_number, pixelnumber*pixelnumber), flattened pixel array
    """
    processed_data = np.empty((image_number-start,pixel_number,pixel_number,5))
    radius = radius*u.arcsec
    for i in range(image_number-start):
        img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=radius)
        #img_green = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSr'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #img_red = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSi'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #print(img)
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/2)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        empty_image = np.empty((pixel_number,pixel_number,5))
        for j in range(5):
            empty_image[:,:,j] = img[j][0].data
        #if i == 0:
        #    print(img[0][0].header)
        #processed_data[i,:,:,:] = empty_image
        save_string = 'array_number_'+str(i+start)
        np.save('C:\\Users\qwsaz\\Research_NCSA\\image_arrays\\{}'.format(save_string), empty_image)
        print(i+start)
    
#should run in 8 hours to go through 10,000 images. 
def pre_process_images(RA,DEC,pixel_number = 64,image_number = 2, start=0, radius=200):
    """
    This function will take in an N dimensional RA and DEC array, look up image files from skyquery, place those files in a
    flattened array.
    
    Parameters:
    RA, array, hold right ascensions for object i, N dim
    DEC, array, holds declination for object i, N dim
    pixel_number, int, tells the square pixel size of the skyquery
    image_number, int, tells how many images to pull from our N dim, sets dim of output array
    
    OUTPUT:
    processed_data: array with dimensions: (image_number, pixelnumber*pixelnumber), flattened pixel array
    """
    processed_data = np.empty((image_number-start,pixel_number,pixel_number,5))
    radius = radius*u.arcsec
    for i in range(image_number-start):
        img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=radius)
        #img_green = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSr'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #img_red = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSi'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
        #print(img)
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/2)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/4)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/8)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        if img == []:
            img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=(radius*(1/20)))
            print('whoops {} is zoomed in a bit'.format(i+start))
        empty_image = np.zeros((pixel_number,pixel_number,5))
        if img == []:
            img = np.zeros((64,64,5))
            print('fuck {} is all zeros'.format(i+start))  
        else:
            for j in range(5):
                empty_image[:,:,j] = img[j][0].data
        #if i == 0:
        #    print(img[0][0].header)
        #processed_data[i,:,:,:] = empty_image
        save_string = 'array_number_'+str(i+start)
        np.save('C:\\Users\qwsaz\\Research_NCSA\\image_arrays\\{}'.format(save_string), empty_image)
        print(i+start)
    
#should run in 8 hours to go through 10,000 images.

# %%
#1292 doesn't exist? we could probably get the same data in a different way, or try again later
#1385 doesn't exist?
#1410 doesn't exist
#1412 wtf
#1416
#1423
#1516 all zeros - 1530
#1686 HTTP error???
#4040
(processed_data_one) = pre_process_images(RA,DEC,pixel_number = 64,image_number = 10000, start=4159)
# Out:
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036356806742_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036356806742_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036356806742_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036356806742_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036356806742_5.fits [Done]
# 4109
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454132677338_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454132677338_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454132677338_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454132677338_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454132677338_5.fits [Done]
# 4110
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036454121042_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036454121042_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036454121042_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036454121042_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036454121042_5.fits [Done]
# 4111
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036490199522_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036490199522_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036490199522_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036490199522_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036490199522_5.fits [Done]
# 4112
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454249788322_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454249788322_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454249788322_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454249788322_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454249788322_5.fits [Done]
# 4113
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036591507838_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036591507838_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036591507838_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036591507838_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036591507838_5.fits [Done]
# 4114
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454348094311_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454348094311_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454348094311_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454348094311_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454348094311_5.fits [Done]
# 4115
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454391870474_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454391870474_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454391870474_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454391870474_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454391870474_5.fits [Done]
# 4116
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454424385990_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454424385990_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454424385990_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454424385990_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454424385990_5.fits [Done]
# 4117
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036771752567_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036771752567_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036771752567_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036771752567_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036771752567_5.fits [Done]
# 4118
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454518083699_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454518083699_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454518083699_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454518083699_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454518083699_5.fits [Done]
# 4119
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454562425886_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454562425886_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454562425886_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454562425886_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454562425886_5.fits [Done]
# 4120
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036884006973_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036884006973_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036884006973_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036884006973_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036884006973_5.fits [Done]
# 4121
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036985167369_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036985167369_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036985167369_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036985167369_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13036985167369_5.fits [Done]
# 4122
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037032793490_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037032793490_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037032793490_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037032793490_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037032793490_5.fits [Done]
# 4123
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037079155320_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037079155320_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037079155320_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037079155320_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037079155320_5.fits [Done]
# 4124
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454833077687_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454833077687_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454833077687_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454833077687_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1454833077687_5.fits [Done]
# 4125
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037178643177_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037178643177_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037178643177_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037178643177_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037178643177_5.fits [Done]
# 4126
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037225467126_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037225467126_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037225467126_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037225467126_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037225467126_5.fits [Done]
# 4127
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037263648246_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037263648246_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037263648246_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037263648246_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037263648246_5.fits [Done]
# 4128
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455023517679_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455023517679_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455023517679_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455023517679_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455023517679_5.fits [Done]
# 4129
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455088801447_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455088801447_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455088801447_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455088801447_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455088801447_5.fits [Done]
# 4130
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037528357719_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037528357719_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037528357719_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037528357719_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037528357719_5.fits [Done]
# 4131
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037671833871_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037671833871_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037671833871_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037671833871_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037671833871_5.fits [Done]
# 4132
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037758941971_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037758941971_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037758941971_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037758941971_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037758941971_5.fits [Done]
# 4133
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037809743203_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037809743203_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037809743203_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037809743203_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037809743203_5.fits [Done]
# 4134
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037844689715_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037844689715_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037844689715_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037844689715_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13037844689715_5.fits [Done]
# 4135
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455593657051_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455593657051_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455593657051_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455593657051_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455593657051_5.fits [Done]
# 4136
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455699377742_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455699377742_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455699377742_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455699377742_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455699377742_5.fits [Done]
# 4137
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455730041308_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455730041308_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455730041308_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455730041308_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1455730041308_5.fits [Done]
# 4138
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038060628862_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038060628862_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038060628862_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038060628862_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038060628862_5.fits [Done]
# 4139
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038229508786_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038229508786_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038229508786_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038229508786_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038229508786_5.fits [Done]
# 4140
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456052061819_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456052061819_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456052061819_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456052061819_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456052061819_5.fits [Done]
# 4141
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038371964811_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038371964811_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038371964811_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038371964811_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038371964811_5.fits [Done]
# 4142
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038415344247_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038415344247_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038415344247_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038415344247_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038415344247_5.fits [Done]
# 4143
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038447408245_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038447408245_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038447408245_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038447408245_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038447408245_5.fits [Done]
# 4144
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038492013913_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038492013913_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038492013913_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038492013913_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038492013913_5.fits [Done]
# 4145
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038527518584_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038527518584_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038527518584_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038527518584_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038527518584_5.fits [Done]
# 4146
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038564385905_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038564385905_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038564385905_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038564385905_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038564385905_5.fits [Done]
# 4147
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038704830061_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038704830061_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038704830061_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038704830061_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038704830061_5.fits [Done]
# 4148
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456536270254_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456536270254_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456536270254_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456536270254_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456536270254_5.fits [Done]
# 4149
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038869194491_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038869194491_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038869194491_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038869194491_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038869194491_5.fits [Done]
# 4150
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038913926903_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038913926903_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038913926903_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038913926903_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13038913926903_5.fits [Done]
# 4151
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456679188943_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456679188943_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456679188943_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456679188943_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456679188943_5.fits [Done]
# 4152
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456826319841_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456826319841_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456826319841_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456826319841_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456826319841_5.fits [Done]
# 4153
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456954765254_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456954765254_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456954765254_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456954765254_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1456954765254_5.fits [Done]
# 4154
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039271189969_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039271189969_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039271189969_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039271189969_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039271189969_5.fits [Done]
# 4155
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457086931749_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457086931749_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457086931749_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457086931749_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457086931749_5.fits [Done]
# 4156
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457235093136_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457235093136_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457235093136_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457235093136_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457235093136_5.fits [Done]
# 4157
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457278844842_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457278844842_2.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457278844842_3.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457278844842_4.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv1457278844842_5.fits [Done]
# 4158
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039606956962_1.fits [Done]
# Downloading https://skyview.gsfc.nasa.gov/tempspace/fits/skv13039606956962_2.fits [Done]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b6aff657d326> in <module>()
#       8 #1686 HTTP error???
#       9 #4040
# ---> 10 (processed_data_one) = pre_process_images(RA,DEC,pixel_number = 64,image_number = 10000, start=4109)
#
# <ipython-input-9-96ede16cde68> in pre_process_images(RA, DEC, pixel_number, image_number, start, radius)
#      51     radius = radius*u.arcsec
#      52     for i in range(image_number-start):
# ---> 53         img = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSu','SDSSg','SDSSr','SDSSi','SDSSz'],pixels=(pixel_number,pixel_number), radius=radius)
#      54         #img_green = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSr'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
#      55         #img_red = SkyView.get_images(position=((str(RA[i+start])+','+str(DEC[i+start]))),survey=['SDSSi'],pixels=(pixel_number,pixel_number), radius=radius)[0][0].data.reshape(pixel_number,pixel_number,1)
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astroquery\skyview\core.py in get_images(self, position, survey, coordinates, projection, pixels, scaling, sampler, resolver, deedger, lut, grid, gridlabels, radius, height, width, cache, show_progress)
#     205                                                  cache=cache,
#     206                                                  show_progress=show_progress)
# --> 207         return [obj.get_fits() for obj in readable_objects]
#     208
#     209     @prepend_docstr_nosections(get_images.__doc__)
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astroquery\skyview\core.py in <listcomp>(.0)
#     205                                                  cache=cache,
#     206                                                  show_progress=show_progress)
# --> 207         return [obj.get_fits() for obj in readable_objects]
#     208
#     209     @prepend_docstr_nosections(get_images.__doc__)
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astroquery\utils\commons.py in get_fits(self)
#     363         and return the file parsed as FITS HDUList
#     364         """
# --> 365         filedata = self.get_string()
#     366
#     367         self._fits = fits.HDUList.fromstring(filedata)
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astroquery\utils\commons.py in get_string(self)
#     419         if not hasattr(self, '_string'):
#     420             try:
# --> 421                 with self._readable_object as f:
#     422                     data = f.read()
#     423                     self._string = data
#
# ~\Anaconda3\envs\DAMLA\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astropy\utils\data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout)
#     190             name_or_obj = download_file(
#     191                 name_or_obj, cache=cache, show_progress=show_progress,
# --> 192                 timeout=remote_timeout)
#     193         fileobj = io.FileIO(name_or_obj, 'r')
#     194         if is_url and not cache:
#
# ~\Anaconda3\envs\DAMLA\lib\site-packages\astropy\utils\data.py in download_file(remote_url, cache, show_progress, timeout)
#    1007         if cache:
#    1008             # We don't need to acquire the lock here, since we are only reading
# -> 1009             with shelve.open(urlmapfn) as url2hash:
#    1010                 if url_key in url2hash:
#    1011                     return url2hash[url_key]
#
# ~\Anaconda3\envs\DAMLA\lib\shelve.py in open(filename, flag, protocol, writeback)
#     241     """
#     242
# --> 243     return DbfilenameShelf(filename, flag, protocol, writeback)
#
# ~\Anaconda3\envs\DAMLA\lib\shelve.py in __init__(self, filename, flag, protocol, writeback)
#     225     def __init__(self, filename, flag='c', protocol=None, writeback=False):
#     226         import dbm
# --> 227         Shelf.__init__(self, dbm.open(filename, flag), protocol, writeback)
#     228
#     229
#
# ~\Anaconda3\envs\DAMLA\lib\dbm\__init__.py in open(file, flag, mode)
#      92     else:
#      93         mod = _modules[result]
# ---> 94     return mod.open(file, flag, mode)
#      95
#      96
#
# ~\Anaconda3\envs\DAMLA\lib\dbm\dumb.py in open(file, flag, mode)
#     322         warnings.warn("Flag must be one of 'r', 'w', 'c', or 'n'",
#     323                       DeprecationWarning, stacklevel=2)
# --> 324     return _Database(file, mode, flag=flag)
#
# ~\Anaconda3\envs\DAMLA\lib\dbm\dumb.py in __init__(self, filebasename, mode, flag)
#      69         # Handle the creation
#      70         self._create(flag)
# ---> 71         self._update()
#      72
#      73     def _create(self, flag):
#
# ~\Anaconda3\envs\DAMLA\lib\dbm\dumb.py in _update(self)
#     102             self._modified = False
#     103             with f:
# --> 104                 for line in f:
#     105                     line = line.rstrip()
#     106                     key, pos_and_siz_pair = _ast.literal_eval(line)
#
# ~\Anaconda3\envs\DAMLA\lib\encodings\latin_1.py in decode(self, input, final)
#      23
#      24 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 25     def decode(self, input, final=False):
#      26         return codecs.latin_1_decode(input,self.errors)[0]
#      27
#
# KeyboardInterrupt:
